# %%
# /// script
# requires-python = ">=3.13"
# dependencies = [
#     "numpy",
#     "pandas",
# ]
# ///

# %%
# Simple pandas and numpy demo
import pandas as pd
import numpy as np

# Create a numpy array
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)

# Create a pandas DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Score': [85, 90, 78]
})
print("\nDataFrame:")
print(df)
# Out:
# Array: [1 2 3 4 5]
#
# DataFrame:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     78
